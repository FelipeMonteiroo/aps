# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeMonteiroo/aps/blob/main/Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('-=' * 40)
print('   Seja bem-vindo!')
print('   Este programa irá te informar o quanto de carbono é produzido,'
      '\n   com diferentes tipos de combustiveis, sendo eles: etanol de cana de açúcar,'
      '\n   etanol de milho e combustível fóssil. E o quantos créditos de carbono'
      '\n   você ganhará')
print('-=' * 40)
print(' -------------MENU-------------'
      '\n [1] Etanol de cana de açúcar'
      '\n [2] Etanol de milho'
      '\n [3] Diesel'
      '\n [0] Sair'
      '\n-------------------------------')
c = 0
while True:
    tipo = str(input('Qual tipo de combustível você quer saber? '))
    if tipo == '1':
        l = float(input(f'Quantos litros de etanol de cana de açúcar: '))
        x = l * 0.79 * 1.8
        print(f'{l} litros de etanol de cana de açúcar gera {x:.2f}kg de Co2')
        if 1000 <= x <= 1999:
            print('Você ganhou 1 crédito de carbono!')
            x = 1
        if 2000 <= x <= 2999:
            print('Você ganhou 2 créditos de carbono!')
            x = 2
        if 3000 <= x <= 3999:
            print('Você ganhou 3 créditos de carbono!')
            x = 3
        if 4000 <= x <= 4999:
            print('Você ganhou 4 créditos de carbono!')
            x = 4
        if 5000 <= x <= 5999:
            print('Você ganhou 5 créditos de carbono!')
            x = 5
        totc = x * 80.87
        print(f'Você trocou {x} créditos de carbono por R${totc}')
    if tipo == '2':
        l = float(input(f'Quantos litros de etanol de milho: '))
        x = l * 0.15 * 1.8
        print(f'{l} litros de etanol milho gera {x:.2f}kg de Co2')
        if 1000 <= x <= 1999:
            print('Você ganhou 1 crédito de carbono!')
            x = 1
        if 2000 <= x <= 2999:
            print('Você ganhou 2 créditos de carbono!')
            x = 2
        if 3000 <= x <= 3999:
            print('Você ganhou 3 créditos de carbono!')
            x = 3
        if 4000 <= x <= 4999:
            print('Você ganhou 4 créditos de carbono!')
            x = 4
        if 5000 <= x <= 5999:
            print('Você ganhou 5 créditos de carbono!')
            x = 5
        totc = x * 80.87
        print(f'Você trocou {x} créditos de carbono por R${totc}')
    if tipo == '3':
        l = float(input(f'Quantos litros de diesel: '))
        x = l * 0.85 * 2.6
        print(f'{l} litros de diesel gera {x:.2f}kg de Co2')
        if 1000 <= x <= 1999:
            print('Você ganhou 1 crédito de carbono!')
            x = 1
        if 2000 <= x <= 2999:
            print('Você ganhou 2 créditos de carbono!')
            x = 2
        if 3000 <= x <= 3999:
            print('Você ganhou 3 créditos de carbono!')
            x = 3
        if 4000 <= x <= 4999:
            print('Você ganhou 4 créditos de carbono!')
            x = 4
        if 5000 <= x <= 5999:
            print('Você ganhou 5 créditos de carbono!')
            x = 5
        else:
            x
        totc = x * 80.87
        print(f'Você trocou {x} créditos de carbono por R${totc}')
    if tipo == '0':
        break
print('FIM DO PROGRAMA')
